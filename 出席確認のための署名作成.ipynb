# %% [markdown]
# <a href="https://colab.research.google.com/github/ohyamaty/test/blob/main/%E5%87%BA%E5%B8%AD%E7%A2%BA%E8%AA%8D%E3%81%AE%E3%81%9F%E3%82%81%E3%81%AE%E7%BD%B2%E5%90%8D%E4%BD%9C%E6%88%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colabで鍵ペアを作るコード

# %%
from cryptography.hazmat.primitives.asymmetric import ed25519
from cryptography.hazmat.primitives import serialization

# Ed25519の鍵ペアを生成
private_key = ed25519.Ed25519PrivateKey.generate()
public_key = private_key.public_key()

# 秘密鍵をPEM形式に変換
private_pem = private_key.private_bytes(
    encoding=serialization.Encoding.PEM,
    format=serialization.PrivateFormat.PKCS8,
    encryption_algorithm=serialization.NoEncryption()
).decode()

# 公開鍵をPEM形式に変換
public_pem = public_key.public_bytes(
    encoding=serialization.Encoding.PEM,
    format=serialization.PublicFormat.SubjectPublicKeyInfo
).decode()

print("===== 秘密鍵：自分だけで保存．絶対に提出しない =====")
print(private_pem)

print("===== 公開鍵：LMSに提出 =====")
print(public_pem)

# %% [markdown]
# # 署名をつくる作るコード

# %%
from cryptography.hazmat.primitives.asymmetric import ed25519
from cryptography.hazmat.primitives import serialization
import base64

# ここに自分の秘密鍵を貼る
private_pem = b"""
-----BEGIN PRIVATE KEY-----
ここに自分の秘密鍵をコピペ
-----END PRIVATE KEY-----
"""

challenge = "" #ここに教室で提示されたコードを入力

private_key = serialization.load_pem_private_key(
    private_pem,
    password=None
)

signature = private_key.sign(challenge.encode())

# LMSに提出しやすいようにBase64に変換
signature_b64 = base64.b64encode(signature).decode()

print("LMSに提出する署名：")
print(signature_b64)
